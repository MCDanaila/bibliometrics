# %%
from typing import Any
from typing import Dict
from typing import List
from typing import Tuple

import os
import sys
import re
import xmltodict
from devtools import debug
from lxml import etree
from hashlib import md5

TAG = "{http://clarivate.com/schema/wok5.30/public/FullRecord}REC"

# %%
# bigint_limit = 2**64

def cnv_str_md5_int( in_str):
  global bigint_limit

  if not in_str:
    in_str = ""

  # The int call to be able to ensure fit in bigint postgres 

  return str( int( md5( in_str.encode()).hexdigest()[:15], 16))
  # return str( int( md5( in_str.encode()).hexdigest()[:16], 16) % ( bigint_limit))

#Global tags

# Publication

pub_id_idx            =  0
pub_doi_idx           =  1
pub_pmid_idx          =  2
pub_type_idx          =  3
pub_lang_idx          =  4
pub_title_idx         =  5
pub_first_page_idx    =  6
pub_last_page_idx     =  7
pub_pub_date_idx      =  8
pub_pub_year_idx      =  9
pub_pub_month_idx     = 10
pub_volume_idx        = 11
pub_copyright_idx     = 12
pub_wuid_idx          = 13
pub_headings_idx      = 14
pub_subheadings_idx   = 15
pub_subjects_idx      = 16
pub_abstract_idx      = 17
pub_fund_text_idx     = 18
pub_grant_idx         = 19
pub_oa_state_idx      = 20
pub_keywords_idx      = 21
pub_authors_idx       = 22
pub_ref_count_idx     = 23
pub_countries_idx     = 24
pub_unified_names_idx = 25
pub_is_retracted_idx  = 26
pub_mapped_type_idx   = 27
pub_id_hash_idx       = 28
pub_idx_ct            = 29

# Source

src_name_idx          = 0
src_issn_idx          = 1
src_abbrev_idx        = 2
src_publisher_idx     = 3
src_source_abbrev_idx = 4
src_abbrev_iso_idx    = 5
src_abbrev_11_idx     = 6
src_abbrev_29_idx     = 7
src_idx_ct            = 8

# Authors 

aut_wos_standard_idx = 0
aut_name_idx         = 1
aut_given_name_idx   = 2
aut_surname_idx      = 3
aut_suffix_idx       = 4
aut_e_address_idx    = 5
aut_display_name_idx = 6
aut_idx_ct           = 7

empty_aut_str  =  "\t".join( [""] * (aut_idx_ct + 2)) # extra 2 for orcid_id and r_id
empty_aut_hash =  cnv_str_md5_int( empty_aut_str)
empty_aut_str  += "\t" + empty_aut_hash

# Affiliation

aff_org_idx         = 0
aff_org_uni_idx     = 1
aff_sub_orgs_idx    = 2
aff_address_idx     = 3
aff_country_idx     = 4
aff_state_idx       = 5
aff_city_idx        = 6
aff_street_idx      = 7
aff_postal_code_idx = 8
aff_ror_id_idx      = 9
aff_org_id_idx      = 10
aff_idx_ct          = 11


empty_aff_str  = "\t".join( [""] * aff_idx_ct)
empty_aff_str += "\t" + cnv_str_md5_int( empty_aff_str)

# Grants

grant_agency_idx = 0
grant_id_idx     = 1
grant_idx_ct     = 2

empty_grant_str  = "\t".join( [""] * grant_idx_ct)
empty_grant_hash = cnv_str_md5_int( empty_grant_str)
empty_grant_str  += "\t" + empty_grant_hash

oa_hierarchy = {
  "closed" : 0,
  "bronze" : 1,
  "green"  : 2,
  "hybrid" : 3,
  "gold"   : 4
}

pub_aut_hashes    = set()
pub_countries     = set()
pub_unified_names = set()

#>>>> cnv

def cnv( in_string: str, replace = ""):
  return in_string if in_string else replace

#<<<< cnv

#<<<<

def remove_para_xml( text):
  text = re.sub(  r'<p.*?>', '', text)
  return re.sub( r'<\\p>', '', text)

def list_to_string( details):
  # Alchemy takes a list (or makes one) and converts into a string like 
  # {"Diffuse uptake",FDG-PET,"Focal uptake","Thyroid cancer"}

  if not details:
    return "{}"

  if isinstance( details, str):
    details = [ details]

  # The None test looks paranoid, but it's not - I've seen it happen AMB 05-07-24
  # Postgresql HATES " in array elements
  # Quote everything - items with no spaces can have commas, which confuses array AMB 12-07-24
  # Backslashes confuse things too AMB 12-07-24

  # details = ",".join( [ '"' + d  +'"' if " " in d else d for d in [x.replace( '"', '\'') for x in details if x is not None]])
  details = ",".join( [ '"' + d  +'"' for d in [x.replace( '"', '\'').replace( '\\', '') for x in details if x is not None]])

  return "{" + details + "}"

def list_or_string( item, joiner = " "):
  if not item:
    return ""

  return joiner.join( [ remove_para_xml( i) for i in item if i is not None]) if isinstance(item, list) else \
                remove_para_xml( item)

#>>>> get

def get(data, keys, fallback = None):
  try:
    for key in keys:
      data = data[key]
  except ( KeyError, TypeError):
    return fallback

  return data

#<<<< get

def process_open_access( dynamic_data):
  oa_holder = get( dynamic_data, [ "ic_related", "oases"])
  if not oa_holder:
    return "closed"

  if oa_holder[ "@is_OA"] != "Yes" :
    return oa_holder[ "@is_OA"]
  
  oa_dets = oa_holder[ "oas"]

  if isinstance( oa_dets, dict):
    # Simplest case
    type = oa_dets[ "@type"]
    if "green" in type:
      type = "green"
    return type

  oa_state = "closed"
  hier     = 0

  for oa_det in oa_dets:
    type = oa_det[ "@type"]
    if "green" in type:
      type = "green"
    if oa_hierarchy[ type] > hier:
      os_state = type
      hier     = oa_hierarchy[ type]

  return os_state

def process_ids( dynamic_data, pub, src):
  ids = get( dynamic_data, [ "cluster_related", "identifiers", "identifier"])
  if not ids:
    return # Should this be logged? AMB 22.12.23 Nope. 20.08.24 AMB

  if isinstance( ids, dict):
    ids = [ids]

  regular_doi_found = False

  for id in ids:
    this_type = id.get( "@type", "")
    if this_type == "doi":
      pub[ pub_doi_idx] = id.get( "@value", "")
      regular_doi_found = True
    elif this_type == "xref_doi":
      if not regular_doi_found:
        pub[ pub_doi_idx] = id.get( "@value", "")
    elif this_type == "issn":
      src[ src_issn_idx] = id.get( "@value", "")
    elif this_type == "pmid":
      pub[ pub_pmid_idx] = id.get( "@value", "")

def get_pub_lang( language):
  # Maybe make this nicer

  if not language:
    return ""

  if language.get( "@count", "") == "1":
    return list_to_string( get(language, ["language", "#text"]))

  return list_to_string( list( {get(lang, ["#text"]) for lang in language.get( "language")})) # Prevent duplicates

def get_title( static_data):
  source_title = ""
  for title in get( static_data, ["summary", "titles", "title"]):
    if title["@type"] == "source":
      source_title = title["#text"]
    if title["@type"] == "item":
      return title["#text"]

  # Fallback to source title or an empty string

  return source_title

def get_author_keywords( pub_hash, fr_metadata, fh):
  # Note that WoS documentation doesn't reference keywords, so this is guessing

  kwds = get( fr_metadata, ["keywords", "keyword"])
  if not kwds: return ""  # Empty  is for keywords column test

  keywords = []

  if isinstance( kwds, str):
    kwds = [kwds]

  for kwd in kwds:
    # Sometimes WoS has a keyword of a single backslash, which confuses
    # postgresql COPY, so don't store these AMB 24.01.24
    if kwd != "\\" :
      keywords.append( kwd)
      print( "\t".join( [pub_hash, kwd]), file=fh)

  return list_to_string( keywords) # keywords test

def get_wuid( summary):
  edition = get( summary, ["EWUID", "edition"])
  if not edition:
    return ""

  ret = []
  if isinstance(edition, dict):
    edition = [edition]
  for wuid in edition:
    ret.append(get(wuid, ["@value"]))
  return list_to_string( ret)

def get_subjects( catinfo):
  subjects = get( catinfo, [ "subjects", "subject"])

  if subjects:
    if isinstance( subjects, dict):
      return subjects.get( "#text", "")
  
    return list( {s.get( "#text", "") for s in subjects}) # Avoid duplicates

  return None

def get_affiliation_details( address_spec):
  aff = [""] * aff_idx_ct

  # Handle the organization details

  orgs         = address_spec.get( "organizations")
  unified_orgs = None
  main_org     = ""

  if orgs:
    org = orgs.get( "organization")

    if isinstance( org, list):  # Most common
      for org_dets in org:
        print('org_dets: ', org_dets)
        if isinstance( org_dets, dict):
          if org_dets.get( "@pref", "") == "Y":
            if unified_orgs:
              unified_orgs.append( org_dets[ "#text"])
            else:
              unified_orgs = [ org_dets[ "#text"]]
          else:
            if main_org == "" :
              main_org = org_dets[ "#name"]
          print('org_dets istance of dict: ', org_dets)
          aff[ aff_ror_id_idx ] = org_dets.get("@ROR_ID", "")
          aff[ aff_org_id_idx ] = org_dets.get("@org_id", "")
        else:
          print('org_dets NO instance of dict: ', org_dets)
          if main_org == "" :
            main_org = org_dets
    else:
      if isinstance( org, str):
        main_org = org
      else:            # A dict, which is REALLY unlikely
        main_org = org[ "#name"]

  if not main_org and unified_orgs:
    main_org = unified_orgs[ 0]   # A bit dodgy I know. AMB 04.01.24
          
  sub_orgs = address_spec.get( "suborganizations")
  if sub_orgs:
    sub_org = sub_orgs.get( "suborganization")
    if isinstance( sub_org, list):
      aff[ aff_sub_orgs_idx] = list_to_string( [item for item in sub_org])
    else:
      aff[ aff_sub_orgs_idx] = list_to_string( sub_org)

  aff[ aff_org_idx    ] = main_org
  aff[ aff_org_uni_idx] = list_to_string( unified_orgs)

  if unified_orgs:
    pub_unified_names.update( unified_orgs)

  aff[ aff_address_idx    ] = address_spec.get( "full_address")
  aff[ aff_state_idx      ] = address_spec.get( "state"       )
  aff[ aff_city_idx       ] = address_spec.get( "city"        )
  aff[ aff_street_idx     ] = address_spec.get( "street"      )

  country = address_spec.get( "country")
  if country:
    aff[ aff_country_idx] = country
    pub_countries.add( country.upper()) # Should make searching quicker

  zip = address_spec.get( "zip")
  if zip:
    # Only until a reply is given from WoS about relevance of location,
    # use the first found if more than one AMB 04.01.24
    if isinstance( zip, list):
      zip = zip[ 0]
    aff[ aff_postal_code_idx] = zip[ "#text"]

  # Sometimes wos specifies a dictionary entry but doesn't give details

  aff_str = "\t".join( [ i if i else "" for i in aff])
  aff_str += "\t" + cnv_str_md5_int( aff_str)

  return [ address_spec[ "@addr_no"], aff_str]

def get_source_details( summary, handles: Dict): # summary guaranteed non null.
  src = [""] * src_idx_ct

  name = get( summary, [ "publishers", "publisher", "names", "name"])

  # This may coma back to bite - I have a feeling name may be a list sometimes

  if name:
    src[ src_abbrev_idx] = name.get( "display_name", "")

    this_name = name.get( "unified_name", "")

    if not this_name or this_name == "" :    # not this_name should do the same thing, no?
      this_name = name.get( "full_name", "")
      if not this_name or this_name == "" :
        this_name = src[ src_abbrev_idx]
        if not this_name:
          this_name = ""

    src[ src_publisher_idx] = this_name

  titles = get( summary, ["titles", "title"])

  # The "list of titles" is actual a list of identifiers, not actual titles
  if titles:
    for title in titles:
      # No match in python 9.8
      title_type = title.get( "@type", "")

      if title_type == "source":
       src[ src_name_idx] = title.get( "#text", "")
      elif title_type == "issn":
       src[ src_issn_idx] = title.get( "#text", "")
      elif title_type == "source_abbrev":
       src[ src_source_abbrev_idx] = title.get( "#text", "")
      elif title_type == "abbrev_iso":
       src[ src_abbrev_iso_idx] = title.get( "#text", "")
      elif title_type == "abbrev_11":
       src[ src_abbrev_11_idx] = title.get( "#text", "")
      elif title_type == "abbrev_29":
       src[ src_abbrev_29_idx] = title.get( "#text", "")

  return src

def get_author_tsv( aut_rec, contribs):
  aut = [""] * aut_idx_ct   # Why? All values expilitly set AMB 16/6/24

  aut[ aut_wos_standard_idx] = aut_rec.get( "wos_standard")
  aut[ aut_name_idx        ] = aut_rec.get( "full_name"   )
  aut[ aut_given_name_idx  ] = aut_rec.get( "first_name"  )
  aut[ aut_surname_idx     ] = aut_rec.get( "last_name"   )
  aut[ aut_suffix_idx      ] = aut_rec.get( "suffix"      )
  aut[ aut_e_address_idx   ] = aut_rec.get( "email_addr"  )
  aut[ aut_display_name_idx] = aut_rec.get( "display_name")

  # For older pubs, there is either no display name or wos_standard. 
  # Default the one with the other

  if not aut[ aut_wos_standard_idx]:
    aut[ aut_wos_standard_idx] = aut[ aut_display_name_idx]
  elif not aut[ aut_display_name_idx]:
    aut[ aut_display_name_idx] = aut[ aut_wos_standard_idx]

  if contribs:
    contribs = contribs.get( aut[ aut_display_name_idx], [""] * 2)
  else:
    contribs = [""] * 2

  aut += contribs   # index 0 orcid, 1 r_id

  # Need to be defensive here - WoS sometimes specifies empty details

  aut_str = "\t".join( [ i if i else "" for i in aut])

  aut_hash = cnv_str_md5_int( aut_str)

  return [ aut_str + "\t" + aut_hash, aut_hash] # Need aut_hash seperate for authorship

def merge_authorship_details( pub_hash, names, contribs, aff_dets, handles):
  namelist = names[ "name"]
  if isinstance( namelist, dict):
    namelist = [namelist]
  for name in namelist:
    role = name[ "@role"]
    # There are a few roles which don't make too much sense. Anon can be seen as an author. 
    # Not sure about corp though. For the meantime I'm gonna put as author, but
    # this needs discussion.
    # Waiting for a reply from WoS wrt "book"
    # AMB 07.01.24

    if( role == "anon" or role == "corp" or role == "book"):
      role = "author"

    if( role == "author" or role == "book_editor" ):
      [ aut_tsv, aut_hash] = get_author_tsv( name, contribs)
      print( aut_tsv, file=handles[ "author"])
      pub_aut_hashes.add( aut_hash)
        
      header = [ pub_hash, name[ "@seq_no"], role]
      if isinstance( aff_dets, dict):
        addr_no = name.get( "addr_no")
        if not addr_no:
          addr_no = "1"
        aff_dets = aff_dets.get( addr_no)
        if not aff_dets:
          aff_dets = empty_aff_str

      print( "\t".join( header) + "\t" + aut_hash + "\t" + aff_dets, file=handles[ "authorship"])

  # When doing affiliation joins, must allow for no addresses in dict

def get_authorship_details( pub_hash, fr_metadata, summary, contribs, handles):

  contrib_dict = {}

  if contribs:
    if contribs[ "@count"] == "1" :
      contribs = [ contribs[ 'contributor']]
    else:
      contribs = contribs[ 'contributor']
    
    for contrib in contribs:
      dets = contrib[ 'name']
      contrib_dict[ dets[ 'display_name']] = [ dets.get( '@orcid_id'),
                                                 dets.get( '@r_id'    )]

  # Get the address details for the publication. If there are any

  addresses = fr_metadata.get("addresses")

  if( addresses and addresses[ "@count"] != "0"):
    # We have some addresses

    address_name = addresses.get( "address_name")

    # Need to know if the address contains names - if so then we don't
    # need the dictionary approach to addresses

    if isinstance( address_name, dict):
      address_name = [ address_name]

    aff_dict_needed = False
    aff_dict        = {}    # Just in case

    for address in address_name:
      [ addr_id, aff_tsv] = get_affiliation_details( address.get( "address_spec"))
      print( aff_tsv, file=handles[ "affiliation"])

      names = address.get( "names")
      if names:
        merge_authorship_details( pub_hash, names, contrib_dict, aff_tsv, handles)
      else:
        # There may be a reference in the summary section
        aff_dict[ addr_id] = aff_tsv

      # Have any locations but no authors been found - if not need to get them from summary

    if aff_dict:
      merge_authorship_details( pub_hash, summary.get( "names"), contrib_dict, aff_dict, handles)

  else:
    # No locations found
    merge_authorship_details( pub_hash, summary.get( "names"), contrib_dict, empty_aff_str, handles)

def l_d_as_list( list_or_dict): # Maybe have utility functions like this as a module AMB 09.01.24
  if not list_or_dict or isinstance( list_or_dict, list):
    return list_or_dict
  return [ list_or_dict]

def get_grants( pub_hash, grants, handles):
  if not grants or grants[ "@count"] == 0:
    print( pub_hash + "\t" + empty_grant_hash, file=handles[ "publicationgrant"])  # To avoid outer joins
    return

  for grant in l_d_as_list( grants[ "grant"]):
    if grant is None: # I've seen this AMB 05-07-24
      continue

    grant_arr = [""] * grant_idx_ct

    grant_agencies = l_d_as_list( grant.get( "grant_agency"))
    if grant_agencies:
      grant_arr[ grant_agency_idx] = list_to_string( [item if isinstance( item, str) else item[ "#text"] \
                                       for item in grant_agencies])
    grant_ids = grant.get( "grant_ids")
    if grant_ids and grant_ids[ "@count"] != 0:
      grant_arr[ grant_id_idx] = list_to_string( l_d_as_list( grant_ids[ "grant_id"]))

    grant_str = "\t".join( grant_arr)
    hashval   = cnv_str_md5_int( grant_str)

    print( grant_str + "\t" + hashval, file=handles[ "grant"           ])
    print( pub_hash  + "\t" + hashval, file=handles[ "publicationgrant"])

def get_citations( pub_hash, fr_metadata, handle):
  refs = fr_metadata.get( "references")
  if not refs or refs[ "@count"] == "0":
    return 0
  citation_count=0
  ref_list = refs[ "reference"]
  if isinstance( ref_list, dict):
    ref_list = [ ref_list]
  for ref in ref_list:
    uid = ref.get( "uid")
    if uid:
      citation_count += 1
      print( pub_hash + "\t" + cnv_str_md5_int( uid), file=handle)
  return citation_count

def process_pub_types( pub_types, product_type_map, pub):
  if not pub_types:
    return
  if isinstance( pub_types, list):
    try:
      pub_types.remove( "Retracted Publication")
      pub[ pub_is_retracted_idx] = "1"
    except ValueError:
      pub[ pub_is_retracted_idx] = "0"
    pub_types.sort()
    lookup_key = "\t".join( pub_types)
    if pub[ pub_is_retracted_idx] == "1":
      pub_types.append( "Retracted Publication")   # Mahmoud request
  else:
    if pub_types == "Retracted Publication":
      pub[ pub_is_retracted_idx] = "1"
      pub_types  = None
      lookup_key = "ABCXYZ" # This has never been observed 
    else:
      pub[ pub_is_retracted_idx] = "0"
      lookup_key = pub_types

  pub[ pub_type_idx]        = list_to_string( pub_types)
  pub[ pub_mapped_type_idx] = product_type_map.get( lookup_key, "Unknown mapping")

# %%
def wos_parse_record( data, xml_name, already_processed_pubs, product_type_map, handles):
  pub = [""] * pub_idx_ct
  pub_aut_hashes.clear()
  pub_countries.clear()
  pub_unified_names.clear()
  
  pub_id = data.get( "UID", "")   # Maybe should complainif no UID?? AMB 22.12.23

  if pub_id in already_processed_pubs:
    return # No need to do anything

  pub[ pub_id_idx     ] = pub_id
  pub_hash              = cnv_str_md5_int( pub_id)
  pub[ pub_id_hash_idx] = pub_hash

  already_processed_pubs.add( pub_id)

  # churn through the identifiers

  static_data  = data       [ "static_data"        ]
  dynamic_data = data       [ "dynamic_data"       ]
  pub_summary  = static_data[ "summary"            ]
  fr_metadata  = static_data[ "fullrecord_metadata"]

  src = get_source_details( pub_summary, handles)

  process_ids( dynamic_data, pub, src)

  pub[ pub_oa_state_idx] = process_open_access( dynamic_data)

  process_pub_types( get( fr_metadata, [ "normalized_doctypes", "doctype"]), product_type_map, pub)

  pub[ pub_lang_idx]     = get_pub_lang( fr_metadata.get( "languages", None))
  pub[ pub_title_idx]    = get_title( static_data)

  pub_info = pub_summary[ "pub_info"]

  page = pub_info.get( "page", None)
  if page:
    pub[ pub_first_page_idx] = page.get( "@begin", "")
    pub[ pub_last_page_idx ] = page.get( "@end"  , "")

  pub[ pub_pub_year_idx]  = pub_info.get( "@pubyear" , "")
  pub[ pub_pub_month_idx] = pub_info.get( "@pubmonth", "")
  pub[ pub_pub_date_idx]  = pub_info.get( "@sortdate", "")
  pub[ pub_volume_idx]    = pub_info.get( "@vol"     , "")

  pub[ pub_copyright_idx] = data.get( "@r_id_disclaimer", "")   # Why show this?? AMB 22.12.23

  pub[ pub_wuid_idx] = get_wuid( pub_summary) 

  catinfo = fr_metadata.get( "category_info")

  if catinfo:
    pub[ pub_headings_idx   ] = list_to_string( get( catinfo, [ "headings"   , "heading"   ]))
    pub[ pub_subheadings_idx] = list_to_string( get( catinfo, [ "subheadings", "subheading"]))
    # Store subjects as an array AND lookup table - should probably rationalise this AMB 25.11.24
    pub_subjects = get_subjects( catinfo) 
    if pub_subjects:
      pub[ pub_subjects_idx] = list_to_string( pub_subjects)
      for subject in pub_subjects:
        print( f"{pub_hash}\t{subject}", file=handles[ "pubsubject"])
    else:
      pub[ pub_subjects_idx] = None
  else:
    # This is really just for regresion testing. These should be removed later AMB 22,12,23
    pub[ pub_headings_idx] = pub[ pub_subheadings_idx] = pub[ pub_subjects_idx] = list_to_string( None)
	
  pub[ pub_abstract_idx ] = list_or_string( get( fr_metadata, [ "abstracts", "abstract", "abstract_text", "p"]))

  fund_ack = fr_metadata.get( "fund_ack")
  if fund_ack:
    pub[ pub_fund_text_idx] = list_or_string( get( fund_ack, ["fund_text", "p"]))
    get_grants( pub_hash, fund_ack.get( "grants"), handles)
  else:
    get_grants( pub_hash, None, handles) # Create dummy grant

  pub[ pub_keywords_idx] = get_author_keywords( pub_hash, fr_metadata, handles[ "authorkeyword"])

  src_str  = "\t".join( src)
  src_hash = cnv_str_md5_int( src_str)

  get_authorship_details( pub_hash, fr_metadata, pub_summary, static_data.get( "contributors"), handles)

  if len( pub_aut_hashes) == 0 :
    # Paranoia
    pub_aut_hashes.add( empty_aut_hash)
    print( empty_aut_str, file=handles[ "author"])

  pub[ pub_authors_idx] = list_to_string( list( pub_aut_hashes))

  if len( pub_countries):
    pub[ pub_countries_idx] = list_to_string( list( pub_countries))
    
  if len( pub_unified_names):
    pub[ pub_unified_names_idx] = list_to_string( list( pub_unified_names))
    
  pub[ pub_ref_count_idx] = str( get_citations( pub_hash, fr_metadata, handles[ "citation"]))

  print( "\t".join( pub + [xml_name, src_hash]), file=handles[ "publication"])
  print( src_str + "\t" + src_hash, file=handles[ "source"])

  for country in pub_countries:
    print( f"{pub_hash}\t{country}", file=handles[ "pubcountry"])
  for p_u_n in pub_unified_names:
    print( f"{pub_hash}\t{p_u_n}", file=handles[ "puborg"])

# %%
def wos_parser( xml_file              : str ,
                handles               : dict,
                already_processed_pubs : set = set(),
                product_type_map      : dict = {}):
  xml_name = os.path.basename( xml_file)

  print( empty_aff_str  , file=handles[ "affiliation"])
  print( empty_grant_str, file=handles[ "grant"      ])

  # Exact lab used etree code to decode WoS data. They seem to know what they are doing with xml, so_
  # Using lxml will reduce memory footprint

  rec_iter = etree.iterparse( xml_file, tag=TAG)
  for _, record in rec_iter:
    data = etree.tostring( record).decode().replace( "<inf>", "") .replace( "</inf>", ""    ). \
                                            replace( "<sup>", "") .replace( "</sup>", ""    ). \
                                            replace( "\n"   , " ").replace( "\\"    , "\\\\")
    wos_parse_record( xmltodict.parse( data)["REC"], xml_name, already_processed_pubs, product_type_map, handles)
    record.clear()
  # Why - grbage collector will do this del rec_iter

# %%
def wos_ingest_xml(xml_path: str, bcp_dir : str):

  print( f"In python ingest with {xml_path}")

  [dir_path, xml_name] = os.path.split(xml_path)
  handles = {}

  bcp_path = (bcp_dir + "/" + xml_name).replace( ".xml", "") 

  with open( bcp_path + ".publication.bcp"     , "w") as handles[ "publication"     ], \
       open( bcp_path + ".author.bcp"          , "w") as handles[ "author"          ], \
       open( bcp_path + ".authorship.bcp"      , "w") as handles[ "authorship"      ], \
       open( bcp_path + ".source.bcp"          , "w") as handles[ "source"          ], \
       open( bcp_path + ".citation.bcp"        , "w") as handles[ "citation"        ], \
       open( bcp_path + ".affiliation.bcp"     , "w") as handles[ "affiliation"     ], \
       open( bcp_path + ".authorkeyword.bcp"   , "w") as handles[ "authorkeyword"   ], \
       open( bcp_path + ".grant.bcp"           , "w") as handles[ "grant"           ], \
       open( bcp_path + ".publicationgrant.bcp", "w") as handles[ "publicationgrant"], \
       open( bcp_path + ".puborg.bcp"          , "w") as handles[ "puborg"          ], \
       open( bcp_path + ".pubcountry.bcp"      , "w") as handles[ "pubcountry"      ], \
       open( bcp_path + ".pubsubject.bcp"      , "w") as handles[ "pubsubject"      ]:
    wos_parser( xml_path, handles)

# %%
wos_ingest_xml('/home/mdanaila/data/wos/WR_2024_20240112153830_ESCI_0001.xml', '/home/mdanaila/data/wos/bcp')
# Out:
# In python ingest with /home/mdanaila/data/wos/WR_2024_20240112153830_ESCI_0001.xml
# org_dets:  Lehigh Valley Hlth Network
# org_dets NO instance of dict:  Lehigh Valley Hlth Network
# org_dets:  {'@pref': 'Y', '@ROR_ID': 'https://ror.org/0245cg223', '@org_id': '30100007291158', '#text': 'Lehigh Valley Health Network'}
# org_dets istance of dict:  {'@pref': 'Y', '@ROR_ID': 'https://ror.org/0245cg223', '@org_id': '30100007291158', '#text': 'Lehigh Valley Health Network'}
# org_dets:  Cairo Univ
# org_dets NO instance of dict:  Cairo Univ
# org_dets:  {'@pref': 'Y', '#text': 'Egyptian Knowledge Bank (EKB)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Egyptian Knowledge Bank (EKB)'}
# org_dets:  {'@pref': 'Y', '@ROR_ID': 'https://ror.org/03q21mh05', '#text': 'Cairo University'}
# org_dets istance of dict:  {'@pref': 'Y', '@ROR_ID': 'https://ror.org/03q21mh05', '#text': 'Cairo University'}
# org_dets:  {'@pref': 'D', '@org_id': '70000000056487', '#text': 'Cairo University Faculty of Veterinary \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets istance of dict:  {'@pref': 'D', '@org_id': '70000000056487', '#text': 'Cairo University Faculty of Veterinary \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets:  Natl Res Ctr
# org_dets NO instance of dict:  Natl Res Ctr
# org_dets:  {'@pref': 'Y', '#text': 'Egyptian Knowledge Bank (EKB)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Egyptian Knowledge Bank (EKB)'}
# org_dets:  {'@pref': 'Y', '#text': 'National Research Centre (NRC)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'National Research Centre (NRC)'}
# org_dets:  Natl Res Ctr
# org_dets NO instance of dict:  Natl Res Ctr
# org_dets:  {'@pref': 'Y', '#text': 'Egyptian Knowledge Bank (EKB)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Egyptian Knowledge Bank (EKB)'}
# org_dets:  {'@pref': 'Y', '#text': 'National Research Centre (NRC)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'National Research Centre (NRC)'}
# org_dets:  Cairo Univ
# org_dets NO instance of dict:  Cairo Univ
# org_dets:  {'@pref': 'Y', '#text': 'Egyptian Knowledge Bank (EKB)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Egyptian Knowledge Bank (EKB)'}
# org_dets:  {'@pref': 'Y', '#text': 'Cairo University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Cairo University'}
# org_dets:  {'@pref': 'D', '#text': 'Cairo University Faculty of Veterinary \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Cairo University Faculty of Veterinary \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets:  Michigan State Univ
# org_dets NO instance of dict:  Michigan State Univ
# org_dets:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets:  Michigan State Univ
# org_dets NO instance of dict:  Michigan State Univ
# org_dets:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets:  Michigan State Univ
# org_dets NO instance of dict:  Michigan State Univ
# org_dets:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets:  Michigan State Univ
# org_dets NO instance of dict:  Michigan State Univ
# org_dets:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets:  Univ Michigan
# org_dets NO instance of dict:  Univ Michigan
# org_dets:  {'@pref': 'Y', '#text': 'University of Michigan System'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Michigan System'}
# org_dets:  {'@pref': 'Y', '#text': 'University of Michigan'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Michigan'}
# org_dets:  Michigan State Univ
# org_dets NO instance of dict:  Michigan State Univ
# org_dets:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Michigan State University'}
# org_dets:  Harvard Med Sch
# org_dets NO instance of dict:  Harvard Med Sch
# org_dets:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets:  {'@pref': 'Y', '#text': 'Harvard Medical School'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard Medical School'}
# org_dets:  Annamalai Univ
# org_dets NO instance of dict:  Annamalai Univ
# org_dets:  {'@pref': 'Y', '#text': 'Annamalai University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Annamalai University'}
# org_dets:  Yeditepe Univ
# org_dets NO instance of dict:  Yeditepe Univ
# org_dets:  {'@pref': 'Y', '#text': 'Yeditepe University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Yeditepe University'}
# org_dets:  Satbayev Univ
# org_dets NO instance of dict:  Satbayev Univ
# org_dets:  {'@pref': 'Y', '#text': 'Satbayev University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Satbayev University'}
# org_dets:  Yogyakarta State Univ
# org_dets NO instance of dict:  Yogyakarta State Univ
# org_dets:  {'@pref': 'Y', '#text': 'Universitas Negeri Yogyakarta'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universitas Negeri Yogyakarta'}
# org_dets:  LN Gumilev Eurasian Natl Univ
# org_dets NO instance of dict:  LN Gumilev Eurasian Natl Univ
# org_dets:  {'@pref': 'Y', '#text': 'L.N. Gumilyov Eurasian National University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'L.N. Gumilyov Eurasian National University'}
# org_dets:  Univ Negeri Padang
# org_dets NO instance of dict:  Univ Negeri Padang
# org_dets:  {'@pref': 'Y', '#text': 'Universitas Negeri Padang'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universitas Negeri Padang'}
# org_dets:  Univ Pavia
# org_dets NO instance of dict:  Univ Pavia
# org_dets:  {'@pref': 'Y', '#text': 'University of Pavia'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Pavia'}
# org_dets:  STMicroelect SRL
# org_dets NO instance of dict:  STMicroelect SRL
# org_dets:  {'@pref': 'Y', '#text': 'STMicroelectronics'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'STMicroelectronics'}
# org_dets:  Shah Abdul Latif Univ
# org_dets NO instance of dict:  Shah Abdul Latif Univ
# org_dets:  {'@pref': 'Y', '#text': 'Shah Abdul Latif University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Shah Abdul Latif University'}
# org_dets:  Univ Sindh
# org_dets NO instance of dict:  Univ Sindh
# org_dets:  {'@pref': 'Y', '#text': 'University of Sindh'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Sindh'}
# org_dets:  Taiwan Semicond Mfg Co Ltd
# org_dets NO instance of dict:  Taiwan Semicond Mfg Co Ltd
# org_dets:  {'@pref': 'Y', '#text': 'Taiwan Semiconductor Manufacturing Company'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Taiwan Semiconductor Manufacturing Company'}
# org_dets:  Sidi Mohammed Ben Abdellah Univ
# org_dets NO instance of dict:  Sidi Mohammed Ben Abdellah Univ
# org_dets:  {'@pref': 'Y', '#text': 'Sidi Mohamed Ben Abdellah University of Fez'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Sidi Mohamed Ben Abdellah University of Fez'}
# org_dets:  Moulay Ismail Univ
# org_dets NO instance of dict:  Moulay Ismail Univ
# org_dets:  {'@pref': 'Y', '#text': 'Moulay Ismail University of Meknes'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Moulay Ismail University of Meknes'}
# org_dets:  Bangladesh Agr Univ
# org_dets NO instance of dict:  Bangladesh Agr Univ
# org_dets:  {'@pref': 'Y', '#text': 'Bangladesh Agricultural University (BAU)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Bangladesh Agricultural University (BAU)'}
# org_dets:  Bangabandhu Sheikh Mujibur Rahman Agr Univ
# org_dets NO instance of dict:  Bangabandhu Sheikh Mujibur Rahman Agr Univ
# org_dets:  {'@pref': 'Y', '#text': 'Bangabandhu Sheikh Mujibur Rahman \t\t\t\t\t\t\t\t\tAgricultural University (BSMRAU)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Bangabandhu Sheikh Mujibur Rahman \t\t\t\t\t\t\t\t\tAgricultural University (BSMRAU)'}
# org_dets:  Gaziantep Univ
# org_dets NO instance of dict:  Gaziantep Univ
# org_dets:  {'@pref': 'Y', '#text': 'Gaziantep University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Gaziantep University'}
# org_dets:  King Abdulaziz Univ
# org_dets NO instance of dict:  King Abdulaziz Univ
# org_dets:  {'@pref': 'Y', '#text': 'King Abdulaziz University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'King Abdulaziz University'}
# org_dets:  Chung Yuan Christian Univ
# org_dets NO instance of dict:  Chung Yuan Christian Univ
# org_dets:  {'@pref': 'Y', '#text': 'Chung Yuan Christian University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Chung Yuan Christian University'}
# org_dets:  Hsinchu Cathay Gen Hosp
# org_dets NO instance of dict:  Hsinchu Cathay Gen Hosp
# org_dets:  {'@pref': 'Y', '#text': 'Cathay General Hospital'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Cathay General Hospital'}
# org_dets:  En Chu Kong Hosp
# org_dets NO instance of dict:  En Chu Kong Hosp
# org_dets:  {'@pref': 'Y', '#text': 'En Chu Kong Hospital'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'En Chu Kong Hospital'}
# org_dets:  Fu Jen Catholic Univ
# org_dets NO instance of dict:  Fu Jen Catholic Univ
# org_dets:  {'@pref': 'Y', '#text': 'Fu Jen Catholic University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Fu Jen Catholic University'}
# org_dets:  {'@pref': 'D', '#text': 'Fu Jen Catholic University College of \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Fu Jen Catholic University College of \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets:  En Chu Kong Hosp
# org_dets NO instance of dict:  En Chu Kong Hosp
# org_dets:  {'@pref': 'Y', '#text': 'En Chu Kong Hospital'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'En Chu Kong Hospital'}
# org_dets:  Univ Barcelona
# org_dets NO instance of dict:  Univ Barcelona
# org_dets:  {'@pref': 'Y', '#text': 'University of Barcelona'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Barcelona'}
# org_dets:  Univ Gerona
# org_dets NO instance of dict:  Univ Gerona
# org_dets:  {'@pref': 'Y', '#text': 'Universitat de Girona'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universitat de Girona'}
# org_dets:  Univ Distrital Francisco Jose de Caldas
# org_dets NO instance of dict:  Univ Distrital Francisco Jose de Caldas
# org_dets:  {'@pref': 'Y', '#text': 'Universidad Distrital Francisco Jose de \t\t\t\t\t\t\t\t\tCaldas'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad Distrital Francisco Jose de \t\t\t\t\t\t\t\t\tCaldas'}
# org_dets:  Univ Tolima
# org_dets NO instance of dict:  Univ Tolima
# org_dets:  {'@pref': 'Y', '#text': 'Universidad del Tolima'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad del Tolima'}
# org_dets:  Setsunan Univ
# org_dets NO instance of dict:  Setsunan Univ
# org_dets:  {'@pref': 'Y', '#text': 'Setsunan University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Setsunan University'}
# org_dets:  Ritsumeikan Univ
# org_dets NO instance of dict:  Ritsumeikan Univ
# org_dets:  {'@pref': 'Y', '#text': 'Ritsumeikan University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ritsumeikan University'}
# org_dets:  Doshisha Univ
# org_dets NO instance of dict:  Doshisha Univ
# org_dets:  {'@pref': 'Y', '#text': 'Doshisha University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Doshisha University'}
# org_dets:  Setsunan Univ
# org_dets NO instance of dict:  Setsunan Univ
# org_dets:  {'@pref': 'Y', '#text': 'Setsunan University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Setsunan University'}
# org_dets:  Univ Texas Austin
# org_dets NO instance of dict:  Univ Texas Austin
# org_dets:  {'@pref': 'Y', '#text': 'University of Texas System'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Texas System'}
# org_dets:  {'@pref': 'Y', '#text': 'University of Texas Austin'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Texas Austin'}
# org_dets:  Abdelmalek Essaadi Univ
# org_dets NO instance of dict:  Abdelmalek Essaadi Univ
# org_dets:  {'@pref': 'Y', '#text': 'Abdelmalek Essaadi University of Tetouan'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Abdelmalek Essaadi University of Tetouan'}
# org_dets:  {'@pref': 'D', '#text': 'Abdelmalek Essaadi University Faculty of \t\t\t\t\t\t\t\t\tScience'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Abdelmalek Essaadi University Faculty of \t\t\t\t\t\t\t\t\tScience'}
# org_dets:  Tepi Agr Res Ctr
# org_dets NO instance of dict:  Tepi Agr Res Ctr
# org_dets:  {'@pref': 'Y', '#text': 'Ethiopian Institute of Agricultural Research \t\t\t\t\t\t\t\t\t(EIAR)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ethiopian Institute of Agricultural Research \t\t\t\t\t\t\t\t\t(EIAR)'}
# org_dets:  Holeta Agr Res Ctr
# org_dets NO instance of dict:  Holeta Agr Res Ctr
# org_dets:  {'@pref': 'Y', '#text': 'Ethiopian Institute of Agricultural Research \t\t\t\t\t\t\t\t\t(EIAR)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ethiopian Institute of Agricultural Research \t\t\t\t\t\t\t\t\t(EIAR)'}
# org_dets:  Jimma Univ
# org_dets NO instance of dict:  Jimma Univ
# org_dets:  {'@pref': 'Y', '#text': 'Jimma University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Jimma University'}
# org_dets:  {'@pref': 'D', '#text': 'Jimma University College of Agriculture and \t\t\t\t\t\t\t\t\tVeterinary Medicine'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Jimma University College of Agriculture and \t\t\t\t\t\t\t\t\tVeterinary Medicine'}
# org_dets:  Thai Nguyen Univ Informat & Commun Technol
# org_dets NO instance of dict:  Thai Nguyen Univ Informat & Commun Technol
# org_dets:  {'@pref': 'Y', '#text': 'Thai Nguyen University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Thai Nguyen University'}
# org_dets:  Thai Nguyen Univ
# org_dets NO instance of dict:  Thai Nguyen Univ
# org_dets:  {'@pref': 'Y', '#text': 'Thai Nguyen University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Thai Nguyen University'}
# org_dets:  Flinders Univ S Australia
# org_dets NO instance of dict:  Flinders Univ S Australia
# org_dets:  {'@pref': 'Y', '#text': 'Flinders University South Australia'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Flinders University South Australia'}
# org_dets:  {'@pref': 'D', '#text': 'Flinders University College of Nursing and \t\t\t\t\t\t\t\t\tHealth Sciences'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Flinders University College of Nursing and \t\t\t\t\t\t\t\t\tHealth Sciences'}
# org_dets:  {'@pref': 'D', '#text': 'Flinders University Caring Futures Institute'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Flinders University Caring Futures Institute'}
# org_dets:  {'@pref': 'D', '#text': 'Flinders University Research Centre for \t\t\t\t\t\t\t\t\tPalliative Care Death & Dying'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Flinders University Research Centre for \t\t\t\t\t\t\t\t\tPalliative Care Death & Dying'}
# org_dets:  CQuniv Australia
# org_dets NO instance of dict:  CQuniv Australia
# org_dets:  {'@pref': 'Y', '#text': 'Central Queensland University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Central Queensland University'}
# org_dets:  {'@pref': 'D', '#text': 'Central Queensland University School of \t\t\t\t\t\t\t\t\tHealth Medical and Applied Sciences'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Central Queensland University School of \t\t\t\t\t\t\t\t\tHealth Medical and Applied Sciences'}
# org_dets:  Flinders Univ S Australia
# org_dets NO instance of dict:  Flinders Univ S Australia
# org_dets:  {'@pref': 'Y', '#text': 'Flinders University South Australia'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Flinders University South Australia'}
# org_dets:  {'@pref': 'D', '#text': 'Flinders University College of Nursing and \t\t\t\t\t\t\t\t\tHealth Sciences'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Flinders University College of Nursing and \t\t\t\t\t\t\t\t\tHealth Sciences'}
# org_dets:  {'@pref': 'D', '#text': 'Flinders University Caring Futures Institute'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Flinders University Caring Futures Institute'}
# org_dets:  {'@pref': 'D', '#text': 'Flinders University Research Centre for \t\t\t\t\t\t\t\t\tPalliative Care Death & Dying'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Flinders University Research Centre for \t\t\t\t\t\t\t\t\tPalliative Care Death & Dying'}
# org_dets:  Mayo Clin
# org_dets NO instance of dict:  Mayo Clin
# org_dets:  {'@pref': 'Y', '#text': 'Mayo Clinic'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Mayo Clinic'}
# org_dets:  {'@pref': 'Y', '#text': 'Mayo Clinic Phoenix'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Mayo Clinic Phoenix'}
# org_dets:  Univ Sao Paulo
# org_dets NO instance of dict:  Univ Sao Paulo
# org_dets:  {'@pref': 'Y', '#text': 'Universidade de Sao Paulo'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade de Sao Paulo'}
# org_dets:  Rajamangala Univ Technol Thanyaburi
# org_dets NO instance of dict:  Rajamangala Univ Technol Thanyaburi
# org_dets:  {'@pref': 'Y', '#text': 'Rajamangala University of Technology \t\t\t\t\t\t\t\t\tThanyaburi'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Rajamangala University of Technology \t\t\t\t\t\t\t\t\tThanyaburi'}
# org_dets:  Canakkale Onsekiz Mart Univ
# org_dets NO instance of dict:  Canakkale Onsekiz Mart Univ
# org_dets:  {'@pref': 'Y', '#text': 'Canakkale Onsekiz Mart University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Canakkale Onsekiz Mart University'}
# org_dets:  Ege Univ
# org_dets NO instance of dict:  Ege Univ
# org_dets:  {'@pref': 'Y', '#text': 'Ege University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ege University'}
# org_dets:  Celal Bayar Univ
# org_dets NO instance of dict:  Celal Bayar Univ
# org_dets:  {'@pref': 'Y', '#text': 'Celal Bayar University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Celal Bayar University'}
# org_dets:  Canakkale Onsekiz Mart Univ
# org_dets NO instance of dict:  Canakkale Onsekiz Mart Univ
# org_dets:  {'@pref': 'Y', '#text': 'Canakkale Onsekiz Mart University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Canakkale Onsekiz Mart University'}
# org_dets:  Univ Cent Ecuador
# org_dets NO instance of dict:  Univ Cent Ecuador
# org_dets:  {'@pref': 'Y', '#text': 'Universidad Central del Ecuador'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad Central del Ecuador'}
# org_dets:  Univ Murcia
# org_dets NO instance of dict:  Univ Murcia
# org_dets:  {'@pref': 'Y', '#text': 'University of Murcia'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Murcia'}
# org_dets:  Univ Alicante
# org_dets NO instance of dict:  Univ Alicante
# org_dets:  {'@pref': 'Y', '#text': "Universitat d'Alacant"}
# org_dets istance of dict:  {'@pref': 'Y', '#text': "Universitat d'Alacant"}
# org_dets:  Natl Acad Legal Sci Ukraine
# org_dets NO instance of dict:  Natl Acad Legal Sci Ukraine
# org_dets:  {'@pref': 'Y', '#text': 'National Academy of Legal Sciences of Ukraine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'National Academy of Legal Sciences of Ukraine'}
# org_dets:  {'@pref': 'Y', '#text': 'Academician F. H. Burchak Scientific Research \t\t\t\t\t\t\t\t\tInstitute of Private Law & Entrepreneurship of National \t\t\t\t\t\t\t\t\tAcademy of Law Sciences of Ukraine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Academician F. H. Burchak Scientific Research \t\t\t\t\t\t\t\t\tInstitute of Private Law & Entrepreneurship of National \t\t\t\t\t\t\t\t\tAcademy of Law Sciences of Ukraine'}
# org_dets:  NALS Ukraine
# org_dets NO instance of dict:  NALS Ukraine
# org_dets:  {'@pref': 'Y', '#text': 'National Academy of Legal Sciences of Ukraine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'National Academy of Legal Sciences of Ukraine'}
# org_dets:  {'@pref': 'Y', '#text': 'Academician F. H. Burchak Scientific Research \t\t\t\t\t\t\t\t\tInstitute of Private Law & Entrepreneurship of National \t\t\t\t\t\t\t\t\tAcademy of Law Sciences of Ukraine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Academician F. H. Burchak Scientific Research \t\t\t\t\t\t\t\t\tInstitute of Private Law & Entrepreneurship of National \t\t\t\t\t\t\t\t\tAcademy of Law Sciences of Ukraine'}
# org_dets:  Natl Acad Legal Sci Ukraine
# org_dets NO instance of dict:  Natl Acad Legal Sci Ukraine
# org_dets:  {'@pref': 'Y', '#text': 'National Academy of Legal Sciences of Ukraine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'National Academy of Legal Sciences of Ukraine'}
# org_dets:  {'@pref': 'Y', '#text': 'Academician F. H. Burchak Scientific Research \t\t\t\t\t\t\t\t\tInstitute of Private Law & Entrepreneurship of National \t\t\t\t\t\t\t\t\tAcademy of Law Sciences of Ukraine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Academician F. H. Burchak Scientific Research \t\t\t\t\t\t\t\t\tInstitute of Private Law & Entrepreneurship of National \t\t\t\t\t\t\t\t\tAcademy of Law Sciences of Ukraine'}
# org_dets:  NALS Ukraine
# org_dets NO instance of dict:  NALS Ukraine
# org_dets:  {'@pref': 'Y', '#text': 'National Academy of Legal Sciences of Ukraine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'National Academy of Legal Sciences of Ukraine'}
# org_dets:  {'@pref': 'Y', '#text': 'Academician F. H. Burchak Scientific Research \t\t\t\t\t\t\t\t\tInstitute of Private Law & Entrepreneurship of National \t\t\t\t\t\t\t\t\tAcademy of Law Sciences of Ukraine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Academician F. H. Burchak Scientific Research \t\t\t\t\t\t\t\t\tInstitute of Private Law & Entrepreneurship of National \t\t\t\t\t\t\t\t\tAcademy of Law Sciences of Ukraine'}
# org_dets:  Natl Acad Sci Ukraine
# org_dets NO instance of dict:  Natl Acad Sci Ukraine
# org_dets:  {'@pref': 'Y', '#text': 'National Academy of Sciences Ukraine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'National Academy of Sciences Ukraine'}
# org_dets:  Univ Deusto
# org_dets NO instance of dict:  Univ Deusto
# org_dets:  {'@pref': 'Y', '#text': 'University of Deusto'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Deusto'}
# org_dets:  Univ Ramon Llull
# org_dets NO instance of dict:  Univ Ramon Llull
# org_dets:  {'@pref': 'Y', '#text': 'Universitat Ramon Llull'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universitat Ramon Llull'}
# org_dets:  Univ Al Mustansiriyah
# org_dets NO instance of dict:  Univ Al Mustansiriyah
# org_dets:  {'@pref': 'Y', '#text': 'Mustansiriya University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Mustansiriya University'}
# org_dets:  {'@pref': 'D', '#text': 'Mustansiriyah University College of Science'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Mustansiriyah University College of Science'}
# org_dets:  {'@pref': 'D', '#text': 'Mustansiriyah University Department of \t\t\t\t\t\t\t\t\tMathematics'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Mustansiriyah University Department of \t\t\t\t\t\t\t\t\tMathematics'}
# org_dets:  Middle East Univ
# org_dets NO instance of dict:  Middle East Univ
# org_dets:  {'@pref': 'Y', '#text': 'Middle East University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Middle East University'}
# org_dets:  {'@pref': 'D', '#text': 'Middle East University Faculty of Arts and \t\t\t\t\t\t\t\t\tEducational Sciences'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Middle East University Faculty of Arts and \t\t\t\t\t\t\t\t\tEducational Sciences'}
# org_dets:  Razi Univ
# org_dets NO instance of dict:  Razi Univ
# org_dets:  {'@pref': 'Y', '#text': 'Razi University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Razi University'}
# org_dets:  Anhui Polytech Univ
# org_dets NO instance of dict:  Anhui Polytech Univ
# org_dets:  {'@pref': 'Y', '#text': 'Anhui Polytechnic University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Anhui Polytechnic University'}
# org_dets:  Univ Sao Paulo
# org_dets NO instance of dict:  Univ Sao Paulo
# org_dets:  {'@pref': 'Y', '#text': 'Universidade de Sao Paulo'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade de Sao Paulo'}
# org_dets:  Univ Sao Paulo
# org_dets NO instance of dict:  Univ Sao Paulo
# org_dets:  {'@pref': 'Y', '#text': 'Universidade de Sao Paulo'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade de Sao Paulo'}
# org_dets:  Virginia Polytech Inst & State Univ
# org_dets NO instance of dict:  Virginia Polytech Inst & State Univ
# org_dets:  {'@pref': 'Y', '#text': 'Virginia Polytechnic Institute & State \t\t\t\t\t\t\t\t\tUniversity'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Virginia Polytechnic Institute & State \t\t\t\t\t\t\t\t\tUniversity'}
# org_dets:  Showa Univ
# org_dets NO instance of dict:  Showa Univ
# org_dets:  {'@pref': 'Y', '#text': 'Showa University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Showa University'}
# org_dets:  {'@pref': 'D', '#text': 'Showa University Fujigaoka Hospital'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Showa University Fujigaoka Hospital'}
# org_dets:  Showa Univ
# org_dets NO instance of dict:  Showa Univ
# org_dets:  {'@pref': 'Y', '#text': 'Showa University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Showa University'}
# org_dets:  {'@pref': 'D', '#text': 'Showa University Fujigaoka Hospital'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Showa University Fujigaoka Hospital'}
# org_dets:  Indian Inst Technol Tirupati
# org_dets NO instance of dict:  Indian Inst Technol Tirupati
# org_dets:  {'@pref': 'Y', '#text': 'Indian Institute of Technology System (IIT \t\t\t\t\t\t\t\t\tSystem)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Indian Institute of Technology System (IIT \t\t\t\t\t\t\t\t\tSystem)'}
# org_dets:  {'@pref': 'Y', '#text': 'Indian Institute of Technology (IIT) - \t\t\t\t\t\t\t\t\tTirupati'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Indian Institute of Technology (IIT) - \t\t\t\t\t\t\t\t\tTirupati'}
# org_dets:  Indian Inst Technol Bhubaneswar
# org_dets NO instance of dict:  Indian Inst Technol Bhubaneswar
# org_dets:  {'@pref': 'Y', '#text': 'Indian Institute of Technology System (IIT \t\t\t\t\t\t\t\t\tSystem)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Indian Institute of Technology System (IIT \t\t\t\t\t\t\t\t\tSystem)'}
# org_dets:  {'@pref': 'Y', '#text': 'Indian Institute of Technology (IIT) - \t\t\t\t\t\t\t\t\tBhubaneswar'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Indian Institute of Technology (IIT) - \t\t\t\t\t\t\t\t\tBhubaneswar'}
# org_dets:  Indian Inst Technol Tirupati
# org_dets NO instance of dict:  Indian Inst Technol Tirupati
# org_dets:  {'@pref': 'Y', '#text': 'Indian Institute of Technology System (IIT \t\t\t\t\t\t\t\t\tSystem)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Indian Institute of Technology System (IIT \t\t\t\t\t\t\t\t\tSystem)'}
# org_dets:  {'@pref': 'Y', '#text': 'Indian Institute of Technology (IIT) - \t\t\t\t\t\t\t\t\tTirupati'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Indian Institute of Technology (IIT) - \t\t\t\t\t\t\t\t\tTirupati'}
# org_dets:  All India Inst Med Sci
# org_dets NO instance of dict:  All India Inst Med Sci
# org_dets:  {'@pref': 'Y', '#text': 'All India Institute of Medical Sciences \t\t\t\t\t\t\t\t\t(AIIMS) Raipur'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'All India Institute of Medical Sciences \t\t\t\t\t\t\t\t\t(AIIMS) Raipur'}
# org_dets:  Harvard Med Sch
# org_dets NO instance of dict:  Harvard Med Sch
# org_dets:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets:  {'@pref': 'Y', '#text': 'Harvard Medical School'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard Medical School'}
# org_dets:  {'@pref': 'Y', '#text': 'Massachusetts Eye & Ear Infirmary'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Massachusetts Eye & Ear Infirmary'}
# org_dets:  {'@pref': 'D', '#text': 'Harvard Medical School Department of \t\t\t\t\t\t\t\t\tOphthalmology'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Harvard Medical School Department of \t\t\t\t\t\t\t\t\tOphthalmology'}
# org_dets:  {'@pref': 'D', '#text': 'Massachusetts Eye and Ear Department of \t\t\t\t\t\t\t\t\tOphthalmology'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Massachusetts Eye and Ear Department of \t\t\t\t\t\t\t\t\tOphthalmology'}
# org_dets:  Harvard TH Chan Sch Publ Hlth
# org_dets NO instance of dict:  Harvard TH Chan Sch Publ Hlth
# org_dets:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets:  {'@pref': 'Y', '#text': 'Harvard T.H. Chan School of Public Health'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard T.H. Chan School of Public Health'}
# org_dets:  {'@pref': 'D', '#text': 'Harvard University Department of Epidemiology'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Harvard University Department of Epidemiology'}
# org_dets:  Harvard TH Chan Sch Publ Hlth
# org_dets NO instance of dict:  Harvard TH Chan Sch Publ Hlth
# org_dets:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets:  {'@pref': 'Y', '#text': 'Harvard T.H. Chan School of Public Health'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard T.H. Chan School of Public Health'}
# org_dets:  Univ Coimbra
# org_dets NO instance of dict:  Univ Coimbra
# org_dets:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets:  {'@pref': 'D', '#text': 'University of Coimbra Faculty of Medicine'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'University of Coimbra Faculty of Medicine'}
# org_dets:  Ctr Hosp & Univ Coimbra
# org_dets NO instance of dict:  Ctr Hosp & Univ Coimbra
# org_dets:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets:  {'@pref': 'Y', '#text': 'Centro Hospitalar e Universitario de Coimbra \t\t\t\t\t\t\t\t\t(CHUC)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Centro Hospitalar e Universitario de Coimbra \t\t\t\t\t\t\t\t\t(CHUC)'}
# org_dets:  Assoc Innovat & Biomed Res Light & Image
# org_dets NO instance of dict:  Assoc Innovat & Biomed Res Light & Image
# org_dets:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets:  Brigham & Womens Hosp
# org_dets NO instance of dict:  Brigham & Womens Hosp
# org_dets:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets:  {'@pref': 'Y', '#text': "Brigham & Women's Hospital"}
# org_dets istance of dict:  {'@pref': 'Y', '#text': "Brigham & Women's Hospital"}
# org_dets:  {'@pref': 'D', '#text': "Brigham and Women's Hospital Department of \t\t\t\t\t\t\t\t\tMedicine"}
# org_dets istance of dict:  {'@pref': 'D', '#text': "Brigham and Women's Hospital Department of \t\t\t\t\t\t\t\t\tMedicine"}
# org_dets:  {'@pref': 'D', '#text': "Brigham and Women's Hospital Channing \t\t\t\t\t\t\t\t\tDivision of Network Medicine"}
# org_dets istance of dict:  {'@pref': 'D', '#text': "Brigham and Women's Hospital Channing \t\t\t\t\t\t\t\t\tDivision of Network Medicine"}
# org_dets:  Harvard Med Sch
# org_dets NO instance of dict:  Harvard Med Sch
# org_dets:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets:  {'@pref': 'Y', '#text': 'Harvard Medical School'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard Medical School'}
# org_dets:  Harvard TH Chan Sch Publ Hlth
# org_dets NO instance of dict:  Harvard TH Chan Sch Publ Hlth
# org_dets:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets:  {'@pref': 'Y', '#text': 'Harvard T.H. Chan School of Public Health'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard T.H. Chan School of Public Health'}
# org_dets:  {'@pref': 'D', '#text': 'Harvard University Department of \t\t\t\t\t\t\t\t\tBiostatistics'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Harvard University Department of \t\t\t\t\t\t\t\t\tBiostatistics'}
# org_dets:  Harvard Med Sch
# org_dets NO instance of dict:  Harvard Med Sch
# org_dets:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard University'}
# org_dets:  {'@pref': 'Y', '#text': 'Massachusetts Eye & Ear Infirmary'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Massachusetts Eye & Ear Infirmary'}
# org_dets:  {'@pref': 'Y', '#text': 'Harvard Medical School'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Harvard Medical School'}
# org_dets:  Alberta Childrens Prov Gen Hosp
# org_dets NO instance of dict:  Alberta Childrens Prov Gen Hosp
# org_dets:  {'@pref': 'Y', '#text': 'Alberta Childrens Hospital'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Alberta Childrens Hospital'}
# org_dets:  {'@pref': 'Y', '#text': 'University of Calgary'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Calgary'}
# org_dets:  Univ Calgary
# org_dets NO instance of dict:  Univ Calgary
# org_dets:  {'@pref': 'Y', '#text': 'University of Calgary'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Calgary'}
# org_dets:  Univ Calgary
# org_dets NO instance of dict:  Univ Calgary
# org_dets:  {'@pref': 'Y', '#text': 'University of Calgary'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Calgary'}
# org_dets:  {'@pref': 'D', '#text': 'University of Calgary Cumming School of \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'University of Calgary Cumming School of \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets:  {'@pref': 'D', '#text': 'University of Calgary Department of Family \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'University of Calgary Department of Family \t\t\t\t\t\t\t\t\tMedicine'}
# org_dets:  Univ Hosp Ctr Coimbra
# org_dets NO instance of dict:  Univ Hosp Ctr Coimbra
# org_dets:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets:  {'@pref': 'Y', '#text': 'Centro Hospitalar e Universitario de Coimbra \t\t\t\t\t\t\t\t\t(CHUC)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Centro Hospitalar e Universitario de Coimbra \t\t\t\t\t\t\t\t\t(CHUC)'}
# org_dets:  Univ Coimbra
# org_dets NO instance of dict:  Univ Coimbra
# org_dets:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets:  Hosp & Univ Ctr Coimbra
# org_dets NO instance of dict:  Hosp & Univ Ctr Coimbra
# org_dets:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade de Coimbra'}
# org_dets:  {'@pref': 'Y', '#text': 'Centro Hospitalar e Universitario de Coimbra \t\t\t\t\t\t\t\t\t(CHUC)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Centro Hospitalar e Universitario de Coimbra \t\t\t\t\t\t\t\t\t(CHUC)'}
# org_dets:  Univ Alicante
# org_dets NO instance of dict:  Univ Alicante
# org_dets:  {'@pref': 'Y', '#text': "Universitat d'Alacant"}
# org_dets istance of dict:  {'@pref': 'Y', '#text': "Universitat d'Alacant"}
# org_dets:  Univ Granada
# org_dets NO instance of dict:  Univ Granada
# org_dets:  {'@pref': 'Y', '#text': 'University of Granada'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Granada'}
# org_dets:  {'@pref': 'Y', '#text': 'Hospital Universitario Virgen de las Nieves'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Hospital Universitario Virgen de las Nieves'}
# org_dets:  Mohamed First Univ
# org_dets NO instance of dict:  Mohamed First Univ
# org_dets:  {'@pref': 'Y', '#text': 'Mohammed First University of Oujda'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Mohammed First University of Oujda'}
# org_dets:  Ibn Tofail Univ
# org_dets NO instance of dict:  Ibn Tofail Univ
# org_dets:  {'@pref': 'Y', '#text': 'Ibn Tofail University of Kenitra'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ibn Tofail University of Kenitra'}
# org_dets:  Sidi Mohamed Ben Abdellah Univ
# org_dets NO instance of dict:  Sidi Mohamed Ben Abdellah Univ
# org_dets:  {'@pref': 'Y', '#text': 'Sidi Mohamed Ben Abdellah University of Fez'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Sidi Mohamed Ben Abdellah University of Fez'}
# org_dets:  Mohamed First Univ
# org_dets NO instance of dict:  Mohamed First Univ
# org_dets:  {'@pref': 'Y', '#text': 'Mohammed First University of Oujda'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Mohammed First University of Oujda'}
# org_dets:  Ibn Zohr Univ
# org_dets NO instance of dict:  Ibn Zohr Univ
# org_dets:  {'@pref': 'Y', '#text': 'Ibn Zohr University of Agadir'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ibn Zohr University of Agadir'}
# org_dets:  Univ Pendidikan Indonesia
# org_dets NO instance of dict:  Univ Pendidikan Indonesia
# org_dets:  {'@pref': 'Y', '#text': 'Universitas Pendidikan Indonesia'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universitas Pendidikan Indonesia'}
# org_dets:  Texas Tech Univ
# org_dets NO instance of dict:  Texas Tech Univ
# org_dets:  {'@pref': 'Y', '#text': 'Texas Tech University System'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Texas Tech University System'}
# org_dets:  {'@pref': 'Y', '#text': 'Texas Tech University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Texas Tech University'}
# org_dets:  {'@pref': 'D', '#text': 'Texas Tech University College of Agricultural \t\t\t\t\t\t\t\t\tSciences and Natural Resources'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Texas Tech University College of Agricultural \t\t\t\t\t\t\t\t\tSciences and Natural Resources'}
# org_dets:  {'@pref': 'D', '#text': 'Texas Tech University Department of Plant \t\t\t\t\t\t\t\t\tSoil Sciences'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Texas Tech University Department of Plant \t\t\t\t\t\t\t\t\tSoil Sciences'}
# org_dets:  Univ Quebec Montreal
# org_dets NO instance of dict:  Univ Quebec Montreal
# org_dets:  {'@pref': 'Y', '#text': 'University of Quebec'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Quebec'}
# org_dets:  {'@pref': 'Y', '#text': 'University of Quebec Montreal'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Quebec Montreal'}
# org_dets:  Comenius Univ
# org_dets NO instance of dict:  Comenius Univ
# org_dets:  {'@pref': 'Y', '#text': 'Comenius University Bratislava'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Comenius University Bratislava'}
# org_dets:  Aix Marseille Univ
# org_dets NO instance of dict:  Aix Marseille Univ
# org_dets:  {'@pref': 'Y', '#text': 'Universite PSL'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universite PSL'}
# org_dets:  {'@pref': 'Y', '#text': 'College de France'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'College de France'}
# org_dets:  {'@pref': 'Y', '#text': 'Aix-Marseille Universite'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Aix-Marseille Universite'}
# org_dets:  {'@pref': 'Y', '#text': 'Institut de Recherche pour le Developpement \t\t\t\t\t\t\t\t\t(IRD)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Institut de Recherche pour le Developpement \t\t\t\t\t\t\t\t\t(IRD)'}
# org_dets:  {'@pref': 'Y', '#text': 'Centre National de la Recherche Scientifique \t\t\t\t\t\t\t\t\t(CNRS)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Centre National de la Recherche Scientifique \t\t\t\t\t\t\t\t\t(CNRS)'}
# org_dets:  {'@pref': 'Y', '#text': 'INRAE'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'INRAE'}
# org_dets:  Comenius Univ
# org_dets NO instance of dict:  Comenius Univ
# org_dets:  {'@pref': 'Y', '#text': 'Comenius University Bratislava'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Comenius University Bratislava'}
# org_dets:  Slovak Acad Sci
# org_dets NO instance of dict:  Slovak Acad Sci
# org_dets:  {'@pref': 'Y', '#text': 'Slovak Academy of Sciences'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Slovak Academy of Sciences'}
# org_dets:  Croatian Geol Survey
# org_dets NO instance of dict:  Croatian Geol Survey
# org_dets:  {'@pref': 'Y', '#text': 'Croatian Geological Survey'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Croatian Geological Survey'}
# org_dets:  Slovak Acad Sci
# org_dets NO instance of dict:  Slovak Acad Sci
# org_dets:  {'@pref': 'Y', '#text': 'Slovak Academy of Sciences'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Slovak Academy of Sciences'}
# org_dets:  {'@pref': 'Y', '#text': 'Earth Science Institute, SAS'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Earth Science Institute, SAS'}
# org_dets:  Parahyangan Catholic Univ
# org_dets NO instance of dict:  Parahyangan Catholic Univ
# org_dets:  {'@pref': 'Y', '#text': 'Universitas Katolik Parahyangan'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universitas Katolik Parahyangan'}
# org_dets:  Univ Calif Los Angeles
# org_dets NO instance of dict:  Univ Calif Los Angeles
# org_dets:  {'@pref': 'Y', '#text': 'University of California System'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of California System'}
# org_dets:  {'@pref': 'Y', '#text': 'University of California Los Angeles'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of California Los Angeles'}
# org_dets:  Univ Jeddah
# org_dets NO instance of dict:  Univ Jeddah
# org_dets:  {'@pref': 'Y', '#text': 'University of Jeddah'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Jeddah'}
# org_dets:  Taif Univ
# org_dets NO instance of dict:  Taif Univ
# org_dets:  {'@pref': 'Y', '#text': 'Taif University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Taif University'}
# org_dets:  {'@pref': 'D', '#text': 'Taif University College of Science'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Taif University College of Science'}
# org_dets:  Univ Southern Maine
# org_dets NO instance of dict:  Univ Southern Maine
# org_dets:  {'@pref': 'Y', '#text': 'University of Maine System'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Maine System'}
# org_dets:  {'@pref': 'Y', '#text': 'University of Southern Maine'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Southern Maine'}
# org_dets:  Miami Univ
# org_dets NO instance of dict:  Miami Univ
# org_dets:  {'@pref': 'Y', '#text': 'University System of Ohio'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University System of Ohio'}
# org_dets:  {'@pref': 'Y', '#text': 'Miami University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Miami University'}
# org_dets:  Canterbury Christ Church Univ
# org_dets NO instance of dict:  Canterbury Christ Church Univ
# org_dets:  {'@pref': 'Y', '#text': 'Canterbury Christ Church University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Canterbury Christ Church University'}
# org_dets:  {'@pref': 'D', '#text': 'Canterbury Christ Church University Faculty \t\t\t\t\t\t\t\t\tof of Medicine Health and Social Care'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Canterbury Christ Church University Faculty \t\t\t\t\t\t\t\t\tof of Medicine Health and Social Care'}
# org_dets:  Canterbury Christ Church Univ
# org_dets NO instance of dict:  Canterbury Christ Church Univ
# org_dets:  {'@pref': 'Y', '#text': 'Canterbury Christ Church University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Canterbury Christ Church University'}
# org_dets:  {'@pref': 'D', '#text': 'Canterbury Christ Church University Faculty \t\t\t\t\t\t\t\t\tof of Medicine Health and Social Care'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Canterbury Christ Church University Faculty \t\t\t\t\t\t\t\t\tof of Medicine Health and Social Care'}
# org_dets:  Univ Playa Ancha
# org_dets NO instance of dict:  Univ Playa Ancha
# org_dets:  {'@pref': 'Y', '#text': 'Universidad de Playa Ancha'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad de Playa Ancha'}
# org_dets:  Univ Andres Bello
# org_dets NO instance of dict:  Univ Andres Bello
# org_dets:  {'@pref': 'Y', '#text': 'Universidad Andres Bello'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad Andres Bello'}
# org_dets:  Univ Extremadura
# org_dets NO instance of dict:  Univ Extremadura
# org_dets:  {'@pref': 'Y', '#text': 'Universidad de Extremadura'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad de Extremadura'}
# org_dets:  Univ Concepcion
# org_dets NO instance of dict:  Univ Concepcion
# org_dets:  {'@pref': 'Y', '#text': 'Universidad de Concepcion'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad de Concepcion'}
# org_dets:  Univ Catolica Maule
# org_dets NO instance of dict:  Univ Catolica Maule
# org_dets:  {'@pref': 'Y', '#text': 'Universidad Catolica del Maule'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad Catolica del Maule'}
# org_dets:  Univ Andres Bello
# org_dets NO instance of dict:  Univ Andres Bello
# org_dets:  {'@pref': 'Y', '#text': 'Universidad Andres Bello'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad Andres Bello'}
# org_dets:  Univ Catolica Santisima Concepcion
# org_dets NO instance of dict:  Univ Catolica Santisima Concepcion
# org_dets:  {'@pref': 'Y', '#text': 'Universidad Catolica de la Santisima \t\t\t\t\t\t\t\t\tConcepcion'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad Catolica de la Santisima \t\t\t\t\t\t\t\t\tConcepcion'}
# org_dets:  Univ Kebangsaan Malaysia
# org_dets NO instance of dict:  Univ Kebangsaan Malaysia
# org_dets:  {'@pref': 'Y', '#text': 'Universiti Kebangsaan Malaysia'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universiti Kebangsaan Malaysia'}
# org_dets:  {'@pref': 'D', '#text': 'National University of Malaysia Faculty of \t\t\t\t\t\t\t\t\tScience and Technology'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'National University of Malaysia Faculty of \t\t\t\t\t\t\t\t\tScience and Technology'}
# org_dets:  Tikrit Univ
# org_dets NO instance of dict:  Tikrit Univ
# org_dets:  {'@pref': 'Y', '#text': 'University of Tikrit'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Tikrit'}
# org_dets:  {'@pref': 'D', '#text': 'Tikrit University College of Science'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Tikrit University College of Science'}
# org_dets:  Mustansiriyah Univ
# org_dets NO instance of dict:  Mustansiriyah Univ
# org_dets:  {'@pref': 'Y', '#text': 'Mustansiriya University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Mustansiriya University'}
# org_dets:  {'@pref': 'D', '#text': 'Mustansiriyah University College of Basic \t\t\t\t\t\t\t\t\tEducation'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Mustansiriyah University College of Basic \t\t\t\t\t\t\t\t\tEducation'}
# org_dets:  {'@pref': 'D', '#text': 'Mustansiriyah University College of Science'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Mustansiriyah University College of Science'}
# org_dets:  {'@pref': 'D', '#text': 'Mustansiriyah University Department of \t\t\t\t\t\t\t\t\tMathematics'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Mustansiriyah University Department of \t\t\t\t\t\t\t\t\tMathematics'}
# org_dets:  Univ Indonesia
# org_dets NO instance of dict:  Univ Indonesia
# org_dets:  {'@pref': 'Y', '#text': 'University of Indonesia'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Indonesia'}
# org_dets:  United Arab Emirates Univ
# org_dets NO instance of dict:  United Arab Emirates Univ
# org_dets:  {'@pref': 'Y', '#text': 'United Arab Emirates University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'United Arab Emirates University'}
# org_dets:  {'@pref': 'D', '#text': 'UAE University College of Science'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'UAE University College of Science'}
# org_dets:  {'@pref': 'D', '#text': 'UAE University Department of Mathematical \t\t\t\t\t\t\t\t\tSciences'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'UAE University Department of Mathematical \t\t\t\t\t\t\t\t\tSciences'}
# org_dets:  Univ Barcelona
# ...
# org_dets:  {'@pref': 'D', '#text': 'University of Pennsylvania Department of \t\t\t\t\t\t\t\t\tGenetics'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'University of Pennsylvania Department of \t\t\t\t\t\t\t\t\tGenetics'}
# org_dets:  Simons Ctr Syst Biol
# org_dets NO instance of dict:  Simons Ctr Syst Biol
# org_dets:  {'@pref': 'Y', '#text': 'Institute for Advanced Study - USA'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Institute for Advanced Study - USA'}
# org_dets:  Univ Seville
# org_dets NO instance of dict:  Univ Seville
# org_dets:  {'@pref': 'Y', '#text': 'University of Sevilla'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Sevilla'}
# org_dets:  Sinop Univ
# org_dets NO instance of dict:  Sinop Univ
# org_dets:  {'@pref': 'Y', '#text': 'Sinop University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Sinop University'}
# org_dets:  Izmir Univ Econ
# org_dets NO instance of dict:  Izmir Univ Econ
# org_dets:  {'@pref': 'Y', '#text': 'Izmir Ekonomi Universitesi'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Izmir Ekonomi Universitesi'}
# org_dets:  Ozyegin Univ
# org_dets NO instance of dict:  Ozyegin Univ
# org_dets:  {'@pref': 'Y', '#text': 'Ozyegin University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ozyegin University'}
# org_dets:  Macquarie Univ
# org_dets NO instance of dict:  Macquarie Univ
# org_dets:  {'@pref': 'Y', '#text': 'Macquarie University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Macquarie University'}
# org_dets:  Macquarie Univ
# org_dets NO instance of dict:  Macquarie Univ
# org_dets:  {'@pref': 'Y', '#text': 'Macquarie University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Macquarie University'}
# org_dets:  Deakin Univ
# org_dets NO instance of dict:  Deakin Univ
# org_dets:  {'@pref': 'Y', '#text': 'Deakin University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Deakin University'}
# org_dets:  Univ New South Wales
# org_dets NO instance of dict:  Univ New South Wales
# org_dets:  {'@pref': 'Y', '#text': 'University of New South Wales Sydney'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of New South Wales Sydney'}
# org_dets:  Univ Southern Calif
# org_dets NO instance of dict:  Univ Southern Calif
# org_dets:  {'@pref': 'Y', '#text': 'University of Southern California'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Southern California'}
# org_dets:  Babasaheb Bhimrao Ambedkar Univ
# org_dets NO instance of dict:  Babasaheb Bhimrao Ambedkar Univ
# org_dets:  {'@pref': 'Y', '#text': 'Babasaheb Bhimrao Ambedkar University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Babasaheb Bhimrao Ambedkar University'}
# org_dets:  VIT Univ
# org_dets NO instance of dict:  VIT Univ
# org_dets:  {'@pref': 'Y', '#text': 'Vellore Institute of Technology (VIT)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Vellore Institute of Technology (VIT)'}
# org_dets:  {'@pref': 'Y', '#text': 'VIT Chennai'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'VIT Chennai'}
# org_dets:  {'@pref': 'D', '#text': 'Vellore Institute of Technology'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Vellore Institute of Technology'}
# org_dets:  {'@pref': 'D', '#text': 'VIT University School of Advanced Science'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'VIT University School of Advanced Science'}
# org_dets:  Univ Arizona
# org_dets NO instance of dict:  Univ Arizona
# org_dets:  {'@pref': 'Y', '#text': 'University of Arizona'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Arizona'}
# org_dets:  Univ Arizona
# org_dets NO instance of dict:  Univ Arizona
# org_dets:  {'@pref': 'Y', '#text': 'University of Arizona'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Arizona'}
# org_dets:  EGADE Business Sch Tecnol Monterrey
# org_dets NO instance of dict:  EGADE Business Sch Tecnol Monterrey
# org_dets:  {'@pref': 'Y', '#text': 'Tecnologico de Monterrey'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Tecnologico de Monterrey'}
# org_dets:  Pontificia Univ Catolica Chile
# org_dets NO instance of dict:  Pontificia Univ Catolica Chile
# org_dets:  {'@pref': 'Y', '#text': 'Pontificia Universidad Catolica de Chile'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Pontificia Universidad Catolica de Chile'}
# org_dets:  Educ Univ Hong Kong
# org_dets NO instance of dict:  Educ Univ Hong Kong
# org_dets:  {'@pref': 'Y', '#text': 'Education University of Hong Kong (EdUHK)'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Education University of Hong Kong (EdUHK)'}
# org_dets:  {'@pref': 'D', '#text': 'The Education University of Hong Kong Faculty \t\t\t\t\t\t\t\t\tof Liberal Arts and Social Sciences'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'The Education University of Hong Kong Faculty \t\t\t\t\t\t\t\t\tof Liberal Arts and Social Sciences'}
# org_dets:  {'@pref': 'D', '#text': 'The Education University of Hong Kong \t\t\t\t\t\t\t\t\tDepartment of Mathematics and Information Technology'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'The Education University of Hong Kong \t\t\t\t\t\t\t\t\tDepartment of Mathematics and Information Technology'}
# org_dets:  Natl Econ Univ
# org_dets NO instance of dict:  Natl Econ Univ
# org_dets:  {'@pref': 'Y', '#text': 'National Economics University - Vietnam'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'National Economics University - Vietnam'}
# org_dets:  Ankara City Hosp
# org_dets NO instance of dict:  Ankara City Hosp
# org_dets:  {'@pref': 'Y', '#text': 'City Hospital Ankara'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'City Hospital Ankara'}
# org_dets:  {'@pref': 'Y', '#text': 'Ministry of Health - Turkey'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ministry of Health - Turkey'}
# org_dets:  Hacettepe Univ
# org_dets NO instance of dict:  Hacettepe Univ
# org_dets:  {'@pref': 'Y', '#text': 'Hacettepe University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Hacettepe University'}
# org_dets:  Ankara Haci Bayram Veli Univ
# org_dets NO instance of dict:  Ankara Haci Bayram Veli Univ
# org_dets:  {'@pref': 'Y', '#text': 'Ankara Haci Bayram Veli University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ankara Haci Bayram Veli University'}
# org_dets:  Univ Santander
# org_dets NO instance of dict:  Univ Santander
# org_dets:  {'@pref': 'Y', '#text': 'Universidad Industrial de Santander'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidad Industrial de Santander'}
# org_dets:  Serv Nacl Aprendizaje
# org_dets NO instance of dict:  Serv Nacl Aprendizaje
# org_dets:  {'@pref': 'Y', '#text': 'Servicio Nacional de Aprendizaje'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Servicio Nacional de Aprendizaje'}
# org_dets:  Univ Fed Piaui
# org_dets NO instance of dict:  Univ Fed Piaui
# org_dets:  {'@pref': 'Y', '#text': 'Universidade Federal do Piaui'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade Federal do Piaui'}
# org_dets:  Univ Fed Minas Gerais
# org_dets NO instance of dict:  Univ Fed Minas Gerais
# org_dets:  {'@pref': 'Y', '#text': 'Universidade Federal de Minas Gerais'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Universidade Federal de Minas Gerais'}
# org_dets:  Kings Coll London
# org_dets NO instance of dict:  Kings Coll London
# org_dets:  {'@pref': 'Y', '#text': 'University of London'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of London'}
# org_dets:  {'@pref': 'Y', '#text': "King's College London"}
# org_dets istance of dict:  {'@pref': 'Y', '#text': "King's College London"}
# org_dets:  Ilam Univ
# org_dets NO instance of dict:  Ilam Univ
# org_dets:  {'@pref': 'Y', '#text': 'Ilam University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ilam University'}
# org_dets:  Ilam Univ
# org_dets NO instance of dict:  Ilam Univ
# org_dets:  {'@pref': 'Y', '#text': 'Ilam University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ilam University'}
# org_dets:  Ariel Univ Israel
# org_dets NO instance of dict:  Ariel Univ Israel
# org_dets:  {'@pref': 'Y', '#text': 'Ariel University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ariel University'}
# org_dets:  Ariel Univ Israel
# org_dets NO instance of dict:  Ariel Univ Israel
# org_dets:  {'@pref': 'Y', '#text': 'Ariel University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Ariel University'}
# org_dets:  Univ Tabuk
# org_dets NO instance of dict:  Univ Tabuk
# org_dets:  {'@pref': 'Y', '#text': 'University of Tabuk'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Tabuk'}
# org_dets:  {'@pref': 'D', '#text': 'University of Tabouk Faculty of Engineering'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'University of Tabouk Faculty of Engineering'}
# org_dets:  Univ Tabuk
# org_dets NO instance of dict:  Univ Tabuk
# org_dets:  {'@pref': 'Y', '#text': 'University of Tabuk'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Tabuk'}
# org_dets:  {'@pref': 'D', '#text': 'University of Tabouk Faculty of Engineering'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'University of Tabouk Faculty of Engineering'}
# org_dets:  IPB Univ
# org_dets NO instance of dict:  IPB Univ
# org_dets:  {'@pref': 'Y', '#text': 'Bogor Agricultural University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Bogor Agricultural University'}
# org_dets:  {'@pref': 'D', '#text': 'IPB University Graduate School'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'IPB University Graduate School'}
# org_dets:  IPB Univ
# org_dets NO instance of dict:  IPB Univ
# org_dets:  {'@pref': 'Y', '#text': 'Bogor Agricultural University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Bogor Agricultural University'}
# org_dets:  {'@pref': 'D', '#text': 'IPB University Faculty of Agricultural \t\t\t\t\t\t\t\t\tEngineering and Technology'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'IPB University Faculty of Agricultural \t\t\t\t\t\t\t\t\tEngineering and Technology'}
# org_dets:  Constantine Philosopher Univ Nitra
# org_dets NO instance of dict:  Constantine Philosopher Univ Nitra
# org_dets:  {'@pref': 'Y', '#text': 'Constantine the Philosopher University in \t\t\t\t\t\t\t\t\tNitra'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Constantine the Philosopher University in \t\t\t\t\t\t\t\t\tNitra'}
# org_dets:  Constantine Philosopher Univ Nitra
# org_dets NO instance of dict:  Constantine Philosopher Univ Nitra
# org_dets:  {'@pref': 'Y', '#text': 'Constantine the Philosopher University in \t\t\t\t\t\t\t\t\tNitra'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Constantine the Philosopher University in \t\t\t\t\t\t\t\t\tNitra'}
# org_dets:  Clin Univ Los Andes
# org_dets NO instance of dict:  Clin Univ Los Andes
# org_dets:  {'@pref': 'Y', '#text': 'Clinica Los Andes'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Clinica Los Andes'}
# org_dets:  Mayo Clin
# org_dets NO instance of dict:  Mayo Clin
# org_dets:  {'@pref': 'Y', '#text': 'Mayo Clinic'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Mayo Clinic'}
# org_dets:  Clin Univ Los Andes
# org_dets NO instance of dict:  Clin Univ Los Andes
# org_dets:  {'@pref': 'Y', '#text': 'Clinica Los Andes'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Clinica Los Andes'}
# org_dets:  Guangxi Univ
# org_dets NO instance of dict:  Guangxi Univ
# org_dets:  {'@pref': 'Y', '#text': 'Guangxi University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Guangxi University'}
# org_dets:  {'@pref': 'D', '#text': 'Guangxi University Guangxi Key Laboratory of \t\t\t\t\t\t\t\t\tElectrochemical Energy Materials'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Guangxi University Guangxi Key Laboratory of \t\t\t\t\t\t\t\t\tElectrochemical Energy Materials'}
# org_dets:  Guangxi Univ
# org_dets NO instance of dict:  Guangxi Univ
# org_dets:  {'@pref': 'Y', '#text': 'Guangxi University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Guangxi University'}
# org_dets:  {'@pref': 'D', '#text': 'Guangxi University School of Resources \t\t\t\t\t\t\t\t\tEnvironment and Materials'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Guangxi University School of Resources \t\t\t\t\t\t\t\t\tEnvironment and Materials'}
# org_dets:  Wenzhou Univ
# org_dets NO instance of dict:  Wenzhou Univ
# org_dets:  {'@pref': 'Y', '#text': 'Wenzhou University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Wenzhou University'}
# org_dets:  {'@pref': 'D', '#text': 'Wenzhou University Key Laboratory of Carbon \t\t\t\t\t\t\t\t\tMaterials of Zhejiang Province'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Wenzhou University Key Laboratory of Carbon \t\t\t\t\t\t\t\t\tMaterials of Zhejiang Province'}
# org_dets:  {'@pref': 'D', '#text': 'Wenzhou University College of Chemistry and \t\t\t\t\t\t\t\t\tMaterials Engineering'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Wenzhou University College of Chemistry and \t\t\t\t\t\t\t\t\tMaterials Engineering'}
# org_dets:  Chengdu Univ
# org_dets NO instance of dict:  Chengdu Univ
# org_dets:  {'@pref': 'Y', '#text': 'Chengdu University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Chengdu University'}
# org_dets:  Yangzhou Univ
# org_dets NO instance of dict:  Yangzhou Univ
# org_dets:  {'@pref': 'Y', '#text': 'Yangzhou University'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Yangzhou University'}
# org_dets:  {'@pref': 'D', '#text': 'Yangzhou University College of Chemistry and \t\t\t\t\t\t\t\t\tChemical Engineering'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'Yangzhou University College of Chemistry and \t\t\t\t\t\t\t\t\tChemical Engineering'}
# org_dets:  Univ Elect Sci & Technol China
# org_dets NO instance of dict:  Univ Elect Sci & Technol China
# org_dets:  {'@pref': 'Y', '#text': 'University of Electronic Science & \t\t\t\t\t\t\t\t\tTechnology of China'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'University of Electronic Science & \t\t\t\t\t\t\t\t\tTechnology of China'}
# org_dets:  {'@pref': 'Y', '#text': 'Shenzhen Institute for Advanced Study, UESTC'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'Shenzhen Institute for Advanced Study, UESTC'}
# org_dets:  City Univ Hong Kong
# org_dets NO instance of dict:  City Univ Hong Kong
# org_dets:  {'@pref': 'Y', '#text': 'City University of Hong Kong'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'City University of Hong Kong'}
# org_dets:  {'@pref': 'D', '#text': 'City University of Hong Kong College of \t\t\t\t\t\t\t\t\tEngineering'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'City University of Hong Kong College of \t\t\t\t\t\t\t\t\tEngineering'}
# org_dets:  {'@pref': 'D', '#text': 'City University of Hong Kong Department of \t\t\t\t\t\t\t\t\tMaterials Science and Engineering'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'City University of Hong Kong Department of \t\t\t\t\t\t\t\t\tMaterials Science and Engineering'}
# org_dets:  {'@pref': 'D', '#text': 'City University of Hong Kong College of \t\t\t\t\t\t\t\t\tScience'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'City University of Hong Kong College of \t\t\t\t\t\t\t\t\tScience'}
# org_dets:  {'@pref': 'D', '#text': 'City University of Hong Kong Department of \t\t\t\t\t\t\t\t\tPhysics'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'City University of Hong Kong Department of \t\t\t\t\t\t\t\t\tPhysics'}
# org_dets:  City Univ Hong Kong
# org_dets NO instance of dict:  City Univ Hong Kong
# org_dets:  {'@pref': 'Y', '#text': 'City University of Hong Kong'}
# org_dets istance of dict:  {'@pref': 'Y', '#text': 'City University of Hong Kong'}
# org_dets:  {'@pref': 'D', '#text': 'City University of Hong Kong College of \t\t\t\t\t\t\t\t\tEngineering'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'City University of Hong Kong College of \t\t\t\t\t\t\t\t\tEngineering'}
# org_dets:  {'@pref': 'D', '#text': 'City University of Hong Kong Department of \t\t\t\t\t\t\t\t\tBiomedical Engineering'}
# org_dets istance of dict:  {'@pref': 'D', '#text': 'City University of Hong Kong Department of \t\t\t\t\t\t\t\t\tBiomedical Engineering'}

# %%
""" 
handles = {}
handles[ "publication"     ] = ".publication.bcp"
handles[ "author"          ] = ".author.bcp"
handles[ "authorship"      ] = ".authorship.bcp"
handles[ "source"          ] =       ".source.bcp"         
handles[ "citation"        ] =       ".citation.bcp"       
handles[ "affiliation"     ] =       ".affiliation.bcp"    
handles[ "authorkeyword"   ] =       ".authorkeyword.bcp"  
handles[ "grant"           ] =      ".grant.bcp"          
handles[ "publicationgrant"] = ".publicationgrant.bcp"
handles[ "puborg"          ] =       ".puborg.bcp"         
handles[ "pubcountry"      ] =       ".pubcountry.bcp"     
handles[ "pubsubject"      ] =      ".pubsubject.bcp"    

xml_file = '/home/mdanaila/data/wos/WR_2024_20240112153830_ESCI_0001.xml'

xml_name = os.path.basename(xml_file)

# Exact lab used etree code to decode WoS data. They seem to know what they are doing with xml, so_
# Using lxml will reduce memory footprint
already_processed_pubs = set()
product_type_map = {}


rec_iter = etree.iterparse( xml_file, tag=TAG)
for _, record in rec_iter:
	data = etree.tostring( record).decode().replace( "<inf>", "") .replace( "</inf>", ""    ). \
										replace( "<sup>", "") .replace( "</sup>", ""    ). \
										replace( "\n"   , " ").replace( "\\"    , "\\\\")
	wos_parse_record( xmltodict.parse( data)["REC"], xml_name, already_processed_pubs, product_type_map, handles)
record.clear() """
# Out:
# ' \nhandles = {}\nhandles[ "publication"     ] = ".publication.bcp"\nhandles[ "author"          ] = ".author.bcp"\nhandles[ "authorship"      ] = ".authorship.bcp"\nhandles[ "source"          ] =       ".source.bcp"         \nhandles[ "citation"        ] =       ".citation.bcp"       \nhandles[ "affiliation"     ] =       ".affiliation.bcp"    \nhandles[ "authorkeyword"   ] =       ".authorkeyword.bcp"  \nhandles[ "grant"           ] =      ".grant.bcp"          \nhandles[ "publicationgrant"] = ".publicationgrant.bcp"\nhandles[ "puborg"          ] =       ".puborg.bcp"         \nhandles[ "pubcountry"      ] =       ".pubcountry.bcp"     \nhandles[ "pubsubject"      ] =      ".pubsubject.bcp"    \n\nxml_file = \'/home/mdanaila/data/wos/WR_2024_20240112153830_ESCI_0001.xml\'\n\nxml_name = os.path.basename(xml_file)\n\n# Exact lab used etree code to decode WoS data. They seem to know what they are doing with xml, so_\n# Using lxml will reduce memory footprint\nalready_processed_pubs = set()\nproduct_type_map = {}\n\n\nrec_iter = etree.iterparse( xml_file, tag=TAG)\nfor _, record in rec_iter:\n\tdata = etree.tostring( record).decode().replace( "<inf>", "") .replace( "</inf>", ""    ). \t\t\t\t\t\t\t\t\t\treplace( "<sup>", "") .replace( "</sup>", ""    ). \t\t\t\t\t\t\t\t\t\treplace( "\n"   , " ").replace( "\\"    , "\\\\")\n\twos_parse_record( xmltodict.parse( data)["REC"], xml_name, already_processed_pubs, product_type_map, handles)\nrecord.clear() '
